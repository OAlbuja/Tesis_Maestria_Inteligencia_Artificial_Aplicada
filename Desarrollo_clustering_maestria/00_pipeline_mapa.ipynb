# %% [markdown]
# # Pipeline Map Until Feature Engineering
#
# ## Goal
# Keep the current work split into small notebooks without losing the analysis thread.
#
# ## Source Notebook
# - `01_data_ingestion_enrichment/copia_01_profiling_empresas_profesional_con_matching - copia.ipynb`

# %% [markdown]
# ## Execution Order
# 1. `01_data_ingestion_enrichment/01_profiling_fuentes_validacion_join.ipynb`
# 2. `02_data_cleaning/01_staging_empresas_normalizadas.ipynb`
# 3. `02_data_cleaning/02_matching_exacto_scvs.ipynb`
# 4. `02_data_cleaning/03_catalogos_y_torneo_fuzzy.ipynb`
# 5. `02_data_cleaning/04_auditoria_llm_y_match_final.ipynb`
# 6. `02_data_cleaning/05_utilidad_consulta_ruc.ipynb`
# 7. `03_feature_engineering/01_base_analitica_empresas.ipynb`
# 8. `03_feature_engineering/02_features_fuentes.ipynb`
# 9. `03_feature_engineering/03_matriz_final_clustering.ipynb`

# %% [markdown]
# ## Rules
# - `01` is only for ingestion, profiling, and integration evidence.
# - `02` is for normalization, matching, audit, and validated entity outputs.
# - `03` starts only after a trusted company or RUC key exists.
# - Each notebook must read the previous notebook output and write its own checkpoint in `outputs/`.
# - Keep notebook names ordered with numeric prefixes.
